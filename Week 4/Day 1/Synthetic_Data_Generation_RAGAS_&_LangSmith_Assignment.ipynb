# %% [markdown]
# # Synthetic Data Generation Using RAGAS - RAG Evaluation with LangSmith
#
# In the following notebook we'll explore a use-case for RAGAS' synthetic testset generation workflow, inspired by the [Evol Instruct](https://arxiv.org/abs/2304.12244) paper.
#
#
#
# - 🤝 BREAKOUT ROOM #1
#   1. Use RAGAS to Generate Synthetic Data
#
# - 🤝 BREAKOUT ROOM #2
#   1. Load them into a LangSmith Dataset
#   2. Evaluate our RAG chain against the synthetic test data
#   3. Make changes to our pipeline
#   4. Evaluate the modified pipeline
#
# SDG is a critical piece of the puzzle, especially for early iteration! Without it, it would not be nearly as easy to get high quality early signal for our application's performance.
#
# Let's dive in!

# %% [markdown]
# # 🤝 BREAKOUT ROOM #1

# %% [markdown]
# ## Task 1: Dependencies and API Keys
#
# We'll need to install a number of API keys and dependencies, since we'll be leveraging a number of great technologies for this pipeline!
#
# 1. OpenAI's endpoints to handle the Synthetic Data Generation
# 2. OpenAI's Endpoints for our RAG pipeline and LangSmith evaluation
# 3. QDrant as our vectorstore
# 4. LangSmith for our evaluation coordinator!
#
# Let's install and provide all the required information below!

# %%
# !pip install -qU langsmith langchain-core langchain-community langchain-openai langchain-qdrant
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 839.3 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.4/288.4 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.4/396.4 kB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 42.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 33.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 20.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.4/259.4 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 35.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 37.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 49.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 15.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires protobuf<5,>=3.20, but you have protobuf 5.28.0 which is incompatible.
# google-ai-generativelanguage 0.6.6 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.0 which is incompatible.
# google-cloud-bigquery-storage 2.25.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.0 which is incompatible.
# google-cloud-datastore 2.19.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.0 which is incompatible.
# google-cloud-firestore 2.16.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.0 which is incompatible.
# tensorboard 2.17.0 requires protobuf!=4.24.0,<5.0.0,>=3.19.6, but you have protobuf 5.28.0 which is incompatible.
# tensorflow 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.28.0 which is incompatible.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 5.28.0 which is incompatible.

# %%
# !pip install -qU pymupdf ragas
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.5/174.5 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 9.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires protobuf<5,>=3.20, but you have protobuf 5.28.0 which is incompatible.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.

# %% [markdown]
# We'll need to provide our LangSmith API key, and set tracing to "true".

# %%
import os
import getpass

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass("LangChain API Key:")
# Out:
# LangChain API Key:··········

# %% [markdown]
# We'll also want to set a project name to make things easier for ourselves.

# %%
from uuid import uuid4

os.environ["LANGCHAIN_PROJECT"] = f"AIM - SDG - {uuid4().hex[0:8]}"

# %% [markdown]
# OpenAI's API Key!

# %%
os.environ["OPENAI_API_KEY"] = getpass.getpass("OpenAI API Key:")
# Out:
# OpenAI API Key:··········

# %% [markdown]
# ## Task 2: Loading Source Documents
#
# In order to create a synthetic dataset, we must first load our source documents!

# %%
from langchain_community.document_loaders import PyMuPDFLoader

documents = PyMuPDFLoader(file_path="https://s2.q4cdn.com/470004039/files/doc_earnings/2024/q3/filing/_10-Q-Q3-2024-As-Filed.pdf").load()

# %% [markdown]
# ## Task 3: Generate Synthetic Data
#
# Let's first take a peek under the RAGAS hood to see what's happening when we generate a single example.
#
# For simplicities sake - we'll look at a flow that results in a reasoning question.

# %% [markdown]
# ### Two LLMs To Rule Them All
#
# - `generator_llm` - will generate our seed questions and evolutions
# - `critic_llm` - will act as a critic to verify if the evolutions are as we expect them to be

# %% [markdown]
# ### Entering the Generation
#
# We'll enter the generation process with our `generate_with_langchain_docs()` method - let's look at how that is implemented:
#
# ```python
# def generate_with_langchain_docs(
#     self,
#     documents: t.Sequence[LCDocument],
#     test_size: int,
#     distributions: t.Optional[Distributions] = None,
#     with_debugging_logs=False,
#     is_async: bool = True,
#     raise_exceptions: bool = True,
#     run_config: t.Optional[RunConfig] = None,
# ):
#     distributions = distributions or {}
#     # chunk documents and add to docstore
#     self.docstore.add_documents(
#         [Document.from_langchain_document(doc) for doc in documents]
#     )
#
#     return self.generate(
#         test_size=test_size,
#         distributions=distributions,
#         with_debugging_logs=with_debugging_logs,
#         is_async=is_async,
#         raise_exceptions=raise_exceptions,
#         run_config=run_config,
#     )
# ```
#
# As you can see - before we do anything, our `doctore` is created using the provided `documents`.
#
# Then, we move on to `generate()`, let's see how that works next!

# %% [markdown]
# ### Generating Examples!
#
# > NOTE: You can see the full implementation [here](https://github.com/explodinggradients/ragas/blob/fe379a1c97d18ce2c203d80432a3da6622337968/src/ragas/testset/generator.py#L234), we'll work through the pseudo-code.
#
# ```python
# function generate(test_size, distributions, other_params...):
#     # Validate and set default values
#     if distributions not provided:
#         distributions = DEFAULT_DISTRIBUTION
#
#     validate_distributions_sum_to_one(distributions)
#
#     set_up_run_config()
#     initialize_docstore()
#
#     # Initialize evolutions
#     for each evolution in distributions:
#         initialize_evolution(evolution)
#
#     set_up_debugging_logs_if_needed()
#
#     # Set up execution environment
#     executor = create_executor()
#
#     # Get initial nodes
#     current_nodes = get_random_nodes_from_docstore(test_size)
#
#     total_evolutions = 0
#
#     # Distribute evolutions based on probabilities
#     for each evolution, probability in distributions:
#         num_samples = round(probability * test_size)
#         for i in random_sample(range(test_size), num_samples):
#             submit_task_to_executor(evolution.evolve, current_nodes[i])
#             total_evolutions += 1
#
#     # Add filler evolutions if needed
#     while total_evolutions < test_size:
#         random_evolution = choose_random_evolution(distributions)
#         submit_task_to_executor(random_evolution.evolve, current_nodes[total_evolutions])
#         total_evolutions += 1
#
#     # Get results
#     try:
#         test_data_rows = executor.get_results()
#         if test_data_rows is empty:
#             raise Exception("No results generated")
#
#     return test_data_rows
# ```
#
# In essence, we:
#
# 1. Do some validation of inputs, and initialize our evolutions.
# 2. Get some random nodes from our docstore.
# 3. Evolve the current nodes based on the desired distribution.
# 4. Fill with sampled evolutions if we're not at the desired number of rows.

# %% [markdown]
# ### Peeking into the Complex Evolution Implementation for Reasoning Questions.
#
# > NOTE: You can see the full implementation [here](https://github.com/explodinggradients/ragas/blob/fe379a1c97d18ce2c203d80432a3da6622337968/src/ragas/testset/evolutions.py#L375). We'll work through the high-level implementation below.
#
# Let's look into how the "Complex Evolution" is implemented:
#
# 1. First, we use [`_aevolve()`](https://github.com/explodinggradients/ragas/blob/fe379a1c97d18ce2c203d80432a3da6622337968/src/ragas/testset/evolutions.py#L289) to generate a "Seed Question".
#
# ```python
# simple_question, current_nodes, _ = await self.se._aevolve(
#             current_tries, current_nodes
#         )
# ```
#
# 2. We use our provided `question_prompt` to generate a reasoning question.
#
# ```python
# result = await self.generator_llm.generate(
#             prompt=question_prompt.format(
#                 question=simple_question, context=merged_node.page_content
#             )
#         )
# ```
#
# > PROMPT (implementation [here](https://github.com/explodinggradients/ragas/blob/fe379a1c97d18ce2c203d80432a3da6622337968/src/ragas/testset/prompts.py#L15)):
#
# ```python
# instruction="""Complicate the given question by rewriting question into a multi-hop reasoning question based on the provided context.
#     Answering the question should require the reader to make multiple logical connections or inferences using the information available in given context.
#     Rules to follow when rewriting question:
#     1. Ensure that the rewritten question can be answered entirely from the information present in the contexts.
#     2. Do not frame questions that contains more than 15 words. Use abbreviation wherever possible.
#     3. Make sure the question is clear and unambiguous.
#     4. phrases like 'based on the provided context','according to the context',etc are not allowed to appear in the question."""
# ```
#
# 3. We verify the question is valid.
#
# ```python
# is_valid_question, feedback = await self.question_filter.filter(
#             reasoning_question
#         )
# ```
#
# > PROMPT (implementation [here](https://github.com/explodinggradients/ragas/blob/fe379a1c97d18ce2c203d80432a3da6622337968/src/ragas/testset/prompts.py#L390))
#
# ```python
# instruction="""
# Asses the given question for clarity and answerability given enough domain knowledge, consider the following criteria:
# 1.Independence: Can the question be understood and answered without needing additional context or access to external references not provided within the question itself? Questions should be self-contained, meaning they do not rely on specific documents, tables, or prior knowledge not shared within the question.
# 2.Clear Intent: Is it clear what type of answer or information the question seeks? The question should convey its purpose without ambiguity, allowing for a direct and relevant response.
# Based on these criteria, assign a verdict of "1" if a question is specific, independent, and has a clear intent, making it understandable and answerable based on the details provided. Assign "0" if it fails to meet one or more of these criteria due to vagueness, reliance on external references, or ambiguity in intent.
# Provide feedback and a verdict in JSON format, including suggestions for improvement if the question is deemed unclear. Highlight aspects of the question that contribute to its clarity or lack thereof, and offer advice on how it could be reframed or detailed for better understanding and answerability.
# """
# ```
#
# 4. We [handle the question](https://github.com/explodinggradients/ragas/blob/fe379a1c97d18ce2c203d80432a3da6622337968/src/ragas/testset/evolutions.py#L401) if it's not valid, otherwise we compress the question:
#
# ```python
# compressed_question = await self._transform_question(
#             prompt=self.compress_question_prompt, question=reasoning_question
#         )
# ```
#
# > PROMPT (implementation [here](https://github.com/explodinggradients/ragas/blob/fe379a1c97d18ce2c203d80432a3da6622337968/src/ragas/testset/prompts.py#L100))
#
# ```python
# instruction="""Rewrite the following question to make it more indirect and shorter while retaining the essence of the original question.
#     The goal is to create a question that conveys the same meaning but in a less direct manner. The rewritten question should shorter so use abbreviation wherever possible."""
# ```
#
# 5. Filter the newly compressed question based on a comparison to the original simple question.
#
# ```python
# if await self.evolution_filter.filter(simple_question, compressed_question):
#             # retry
#             current_nodes = self.se._get_new_random_node()
#             logger.debug(
#                 "evolution_filter failed, retrying with %s", len(current_nodes.nodes)
#             )
#             return await self.aretry_evolve(current_tries, current_nodes)
# ```
#
# `filter` is implemented as follows, with our Critic LLM:
#
# ```python
#     async def filter(self, simple_question: str, compressed_question: str) -> bool:
#         prompt = self.evolution_elimination_prompt.format(
#             question1=simple_question, question2=compressed_question
#         )
#         results = await self.llm.generate(prompt=prompt)
#         results = results.generations[0][0].text.strip()
#         results = await evolution_elimination_parser.aparse(results, prompt, self.llm)
#         results = results.dict() if results is not None else {}
#         logger.debug("evolution filter: %s", results)
#         return results.get("verdict") == 1
# ```
#
# Let's zoom back out now!

# %% [markdown]
# ### Generating Answers:
#
# For answer generation, we simply ask the LLM to answer the question we evolved using the context associated with our evolution - that's it!
#
# We will this:
#
# ```python
# class AnswerFormat(BaseModel):
#     answer: str
#     verdict: int
# ```
#
# Using [this prompt](https://github.com/explodinggradients/ragas/blob/fe379a1c97d18ce2c203d80432a3da6622337968/src/ragas/testset/prompts.py#L143):
#
# ```python
# instruction="""Answer the question using the information from the given context. Output verdict as '1' if answer is present '-1' if answer is not present in the context."""
# ```
#
# This uses our Generator LLM.

# %% [markdown]
# Actually creating our Synthetic Dataset is as simple as running the following cell!

# %%
from ragas.testset.generator import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

generator_llm = ChatOpenAI(model="gpt-3.5-turbo")
critic_llm = ChatOpenAI(model="gpt-4o-mini")
embeddings = OpenAIEmbeddings()

generator = TestsetGenerator.from_langchain(
    generator_llm,
    critic_llm,
    embeddings
)

distributions = {
    simple: 0.5,
    multi_context: 0.4,
    reasoning: 0.1
}

# %% [markdown]
# #### ❓ Question #1:
#
# What do the distributions do *specifically*?
#
# > NOTE: More information is available [here](https://docs.ragas.io/en/latest/concepts/testset_generation.html#in-depth-evolution) on the evolution distributions.

# %% [markdown]
# Let's generate!
#
# > NOTE: This cell will take some time, and also make a lot of calls to OpenAI's endpoints! You may run into rate-limits during this cell!

# %%
testset = generator.generate_with_langchain_docs(documents, 20, distributions, with_debugging_logs=True)
# Out:
# embedding nodes:   0%|          | 0/64 [00:00<?, ?it/s]
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Segment Information', 'Geographic Data', 'Net sales', 'Operating income', 'Research and development expense']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Apple Inc.', 'Cash flows', 'Operating activities', 'Investing activities', 'Financing activities']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Apple Inc.', 'Form 10-Q', 'Financial Statements', "Management's Discussion and Analysis", 'Market Risk']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Earnings Per Share', 'Net income', 'Weighted-average shares', 'Diluted earnings per share', 'Financial Instruments']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Apple Inc.', 'Condensed Consolidated Financial Statements', 'GAAP', 'Net sales', 'Deferred revenue']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Certifications of CEO and CFO', 'Sarbanes-Oxley Act of 2002', 'Form 10-Q', 'Financial condition', 'Results of operations']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Digital Markets Act Investigations', 'European Union', 'Department of Justice Lawsuit', 'Antitrust laws', 'Epic Games lawsuit']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Segment Reporting', 'ASU 2023-07', 'Critical Accounting Estimates', 'Market Risk', 'Controls and Procedures']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Asset-backed securities', 'Total', 'Apple Inc.', 'Form 10-Q']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Apple Inc.', "Consolidated statements of shareholders' equity", 'Common stock and additional paid-in capital', 'Retained earnings/accumulated deficit', 'Other comprehensive income/loss']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Certification', 'Financial statements', 'Disclosure controls and procedures', 'Internal control over financial reporting', 'Chief Executive Officer']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Adjusted Cost', 'Unrealized Gains', 'Unrealized Losses', 'Marketable Securities', 'Fair Value']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Interest Rate Risk', 'Derivative instruments', 'Hedged assets/liabilities', 'Trade receivables', 'Vendor non-trade receivables']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Risk Factors', "Company's business", 'Results of operations', 'Financial condition', 'Stock price']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Financial Statements', 'Net sales', 'Cost of sales', 'Operating income', 'Income before provision for income taxes']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Forward-looking statements', 'Financial condition', 'Results of operations', 'Product introductions', 'Macroeconomic conditions']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Gross Margin', 'Products and Services', 'Operating Expenses', 'Research and Development', 'Net Sales']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['European Commission State Aid Decision', 'General Court of the Court of Justice of the European Union', 'Commercial Paper program', 'Share Repurchase Program', 'Apple Inc. Form 10-Q']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Certification', 'Financial statements', 'Internal control', 'Disclosure controls', 'Chief Financial Officer']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Apple Inc.', 'Q3 2024 Form 10-Q']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Securities Exchange Act of 1934', 'Registrant', 'Luca Maestri', 'Chief Financial Officer', 'Form 10-Q']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Selling, General and Administrative', 'Provision for Income Taxes', 'Liquidity and Capital Resources', 'Manufacturing Purchase Obligations', 'Capital Return Program']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['United States Securities and Exchange Commission', 'Form 10-Q', 'Quarterly report', 'Apple Inc.', 'Nasdaq Stock Market LLC']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Large accelerated filer', 'Accelerated filer', 'Non-accelerated filer', 'Smaller reporting company', 'Emerging growth company']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Apple Inc.', 'Consolidated statements of comprehensive income', 'Net income', 'Other comprehensive income', 'Derivative instruments']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Net sales by category', 'iPhone', 'Mac', 'iPad', 'Wearables, Home and Accessories', 'Services']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Foreign exchange rate risk', 'Cash flow hedges', 'Fluctuations in foreign exchange rates', 'Derivative instruments', 'Accounting considerations']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Net sales by reportable segment', 'Americas', 'Europe', 'Greater China', 'Japan', 'Rest of Asia Pacific']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Share-Based Compensation', 'Restricted Stock Units', 'Fair Value', 'Income tax benefit', 'Legal proceedings']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Exhibits', 'Incorporated by Reference', 'Chief Executive Officer Certification', 'Chief Financial Officer Certification', 'XBRL Document Set']}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Apple Inc.', 'Balance Sheets', 'Current assets', 'Non-current assets', "Shareholders' equity"]}
# [ragas.testset.extractor.DEBUG] topics: {'keyphrases': ['Share repurchase activity', 'Equity Securities', 'Publicly Announced Plans', 'Senior Securities', 'Insider Trading Arrangements']}
# [ragas.testset.docstore.INFO] Document [ID: 0c1f5b64-ad93-4ef0-bfeb-02aba3efef8d] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 0c1f5b64-ad93-4ef0-bfeb-02aba3efef8d] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: c97a6176-4be2-4178-a645-f41e12499cbe] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: c97a6176-4be2-4178-a645-f41e12499cbe] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 23f5b29d-d609-4b74-8d71-1ac6675ae26c] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 23f5b29d-d609-4b74-8d71-1ac6675ae26c] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 5a978dd2-8641-4a80-9dbc-813ea3070afc] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 5a978dd2-8641-4a80-9dbc-813ea3070afc] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 88dd3351-e937-4698-aaf9-23062a3ebfba] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 88dd3351-e937-4698-aaf9-23062a3ebfba] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 3e5a6622-c859-44d3-807d-a4c50d0d8185] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 3e5a6622-c859-44d3-807d-a4c50d0d8185] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: dabe5574-7b2c-4cb5-9d7b-52872a448c89] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: dabe5574-7b2c-4cb5-9d7b-52872a448c89] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 02696663-2154-4715-ae70-e854a42f8a62] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 02696663-2154-4715-ae70-e854a42f8a62] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 90cf652c-7f49-46eb-ba57-d7c0b0ad5655] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 90cf652c-7f49-46eb-ba57-d7c0b0ad5655] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: db458df6-70f2-41ff-b91d-426a9093e0db] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: db458df6-70f2-41ff-b91d-426a9093e0db] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: ea22e3a2-fae1-4fac-b6dd-decc75d4214b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: ea22e3a2-fae1-4fac-b6dd-decc75d4214b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: a7c810f2-e5a8-4168-9ddc-9b621013043a] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: a7c810f2-e5a8-4168-9ddc-9b621013043a] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: dd498edf-4880-4b7f-a798-5a80023bc80b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: dd498edf-4880-4b7f-a798-5a80023bc80b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 9ba06392-cc53-4e95-b266-f5a047b66f4b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 9ba06392-cc53-4e95-b266-f5a047b66f4b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 85615c2c-b167-4ea3-904a-bdcb02641556] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 85615c2c-b167-4ea3-904a-bdcb02641556] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 3d3af4fb-24df-4b8f-8b71-e5a8c4877f35] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 3d3af4fb-24df-4b8f-8b71-e5a8c4877f35] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: b24d0a5f-82aa-4c10-b33b-0ca7a95d32d8] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: b24d0a5f-82aa-4c10-b33b-0ca7a95d32d8] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 4658df62-781a-4748-8949-5c96cc90991d] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 4658df62-781a-4748-8949-5c96cc90991d] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: e6d733c4-b00f-41b9-806b-436397208a10] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: e6d733c4-b00f-41b9-806b-436397208a10] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 2a547de8-0a6e-410f-86b5-4c046a626672] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 2a547de8-0a6e-410f-86b5-4c046a626672] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: e88f2e90-e240-4319-85df-5e51b0eda15c] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: e88f2e90-e240-4319-85df-5e51b0eda15c] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: d3d15a25-5ac6-4efa-8984-6122607dac17] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: d3d15a25-5ac6-4efa-8984-6122607dac17] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 8cd33bb2-e2dc-4d17-98cb-2192a1129065] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 8cd33bb2-e2dc-4d17-98cb-2192a1129065] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: f8eddc5e-7c2e-43ee-acab-de97146f5759] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: f8eddc5e-7c2e-43ee-acab-de97146f5759] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: b15e58a7-8a85-488b-bc1e-2e60a28e0674] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: b15e58a7-8a85-488b-bc1e-2e60a28e0674] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 43aa55ba-482f-4786-a82d-426d1b25b4c5] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 43aa55ba-482f-4786-a82d-426d1b25b4c5] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: b53fb697-1e76-4f7d-b6d6-4c50ab16fb3b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: b53fb697-1e76-4f7d-b6d6-4c50ab16fb3b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 5337eb74-609e-4944-9c1c-f594c93f9eeb] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 5337eb74-609e-4944-9c1c-f594c93f9eeb] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 9e58b126-d6b8-4692-9b7a-793679f619ab] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 9e58b126-d6b8-4692-9b7a-793679f619ab] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 25f7374e-005d-459b-b408-ce2319f63cc8] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 25f7374e-005d-459b-b408-ce2319f63cc8] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 3c1f4362-ff08-4b67-98cd-abc301a38a4f] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 3c1f4362-ff08-4b67-98cd-abc301a38a4f] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 60402a42-1da3-4641-87e0-be8fa60ad393] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 60402a42-1da3-4641-87e0-be8fa60ad393] has no filename, using `doc_id` instead
# [ragas.testset.docstore.WARNING] Filename and doc_id are the same for all nodes.
# [ragas.testset.docstore.INFO] Document [ID: 0c1f5b64-ad93-4ef0-bfeb-02aba3efef8d] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: c97a6176-4be2-4178-a645-f41e12499cbe] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: c97a6176-4be2-4178-a645-f41e12499cbe] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 23f5b29d-d609-4b74-8d71-1ac6675ae26c] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 23f5b29d-d609-4b74-8d71-1ac6675ae26c] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 5a978dd2-8641-4a80-9dbc-813ea3070afc] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 5a978dd2-8641-4a80-9dbc-813ea3070afc] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 88dd3351-e937-4698-aaf9-23062a3ebfba] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 88dd3351-e937-4698-aaf9-23062a3ebfba] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 3e5a6622-c859-44d3-807d-a4c50d0d8185] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 3e5a6622-c859-44d3-807d-a4c50d0d8185] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: dabe5574-7b2c-4cb5-9d7b-52872a448c89] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: dabe5574-7b2c-4cb5-9d7b-52872a448c89] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 02696663-2154-4715-ae70-e854a42f8a62] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 02696663-2154-4715-ae70-e854a42f8a62] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 90cf652c-7f49-46eb-ba57-d7c0b0ad5655] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 90cf652c-7f49-46eb-ba57-d7c0b0ad5655] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: db458df6-70f2-41ff-b91d-426a9093e0db] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: db458df6-70f2-41ff-b91d-426a9093e0db] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: ea22e3a2-fae1-4fac-b6dd-decc75d4214b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: ea22e3a2-fae1-4fac-b6dd-decc75d4214b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: a7c810f2-e5a8-4168-9ddc-9b621013043a] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: a7c810f2-e5a8-4168-9ddc-9b621013043a] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: dd498edf-4880-4b7f-a798-5a80023bc80b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: dd498edf-4880-4b7f-a798-5a80023bc80b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 9ba06392-cc53-4e95-b266-f5a047b66f4b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 9ba06392-cc53-4e95-b266-f5a047b66f4b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 85615c2c-b167-4ea3-904a-bdcb02641556] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 85615c2c-b167-4ea3-904a-bdcb02641556] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 3d3af4fb-24df-4b8f-8b71-e5a8c4877f35] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 3d3af4fb-24df-4b8f-8b71-e5a8c4877f35] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: b24d0a5f-82aa-4c10-b33b-0ca7a95d32d8] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: b24d0a5f-82aa-4c10-b33b-0ca7a95d32d8] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 4658df62-781a-4748-8949-5c96cc90991d] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 4658df62-781a-4748-8949-5c96cc90991d] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: e6d733c4-b00f-41b9-806b-436397208a10] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: e6d733c4-b00f-41b9-806b-436397208a10] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 2a547de8-0a6e-410f-86b5-4c046a626672] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 2a547de8-0a6e-410f-86b5-4c046a626672] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: e88f2e90-e240-4319-85df-5e51b0eda15c] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: e88f2e90-e240-4319-85df-5e51b0eda15c] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: d3d15a25-5ac6-4efa-8984-6122607dac17] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: d3d15a25-5ac6-4efa-8984-6122607dac17] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 8cd33bb2-e2dc-4d17-98cb-2192a1129065] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 8cd33bb2-e2dc-4d17-98cb-2192a1129065] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: f8eddc5e-7c2e-43ee-acab-de97146f5759] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: f8eddc5e-7c2e-43ee-acab-de97146f5759] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: b15e58a7-8a85-488b-bc1e-2e60a28e0674] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: b15e58a7-8a85-488b-bc1e-2e60a28e0674] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 43aa55ba-482f-4786-a82d-426d1b25b4c5] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 43aa55ba-482f-4786-a82d-426d1b25b4c5] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: b53fb697-1e76-4f7d-b6d6-4c50ab16fb3b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: b53fb697-1e76-4f7d-b6d6-4c50ab16fb3b] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 5337eb74-609e-4944-9c1c-f594c93f9eeb] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 5337eb74-609e-4944-9c1c-f594c93f9eeb] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 9e58b126-d6b8-4692-9b7a-793679f619ab] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 9e58b126-d6b8-4692-9b7a-793679f619ab] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 25f7374e-005d-459b-b408-ce2319f63cc8] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 25f7374e-005d-459b-b408-ce2319f63cc8] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 3c1f4362-ff08-4b67-98cd-abc301a38a4f] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 3c1f4362-ff08-4b67-98cd-abc301a38a4f] has no filename, using `doc_id` instead
# [ragas.testset.docstore.INFO] Document [ID: 60402a42-1da3-4641-87e0-be8fa60ad393] has no filename, using `doc_id` instead
# Generating:   0%|          | 0/20 [00:00<?, ?it/s]
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 1, 'depth': 3, 'structure': 2, 'relevance': 3, 'score': 2.25}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Adjusted Cost', 'Unrealized Gains', 'Unrealized Losses', 'Marketable Securities', 'Fair Value']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 2, 'relevance': 3, 'score': 2.5}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Digital Markets Act Investigations', 'European Union', 'Department of Justice Lawsuit', 'Antitrust laws', 'Epic Games lawsuit']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 3, 'relevance': 3, 'score': 2.75}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['European Commission State Aid Decision', 'General Court of the Court of Justice of the European Union', 'Commercial Paper program', 'Share Repurchase Program', 'Apple Inc. Form 10-Q']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 1, 'depth': 3, 'structure': 2, 'relevance': 3, 'score': 2.25}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Adjusted Cost', 'Unrealized Gains', 'Unrealized Losses', 'Marketable Securities', 'Fair Value']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 3, 'depth': 3, 'structure': 3, 'relevance': 3, 'score': 3.0}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Certification', 'Financial statements', 'Disclosure controls and procedures', 'Internal control over financial reporting', 'Chief Executive Officer']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 3, 'relevance': 3, 'score': 2.75}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Share repurchase activity', 'Equity Securities', 'Publicly Announced Plans', 'Senior Securities', 'Insider Trading Arrangements']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 3, 'relevance': 3, 'score': 2.75}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['European Commission State Aid Decision', 'General Court of the Court of Justice of the European Union', 'Commercial Paper program', 'Share Repurchase Program', 'Apple Inc. Form 10-Q']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 3, 'relevance': 3, 'score': 2.75}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Financial Statements', 'Net sales', 'Cost of sales', 'Operating income', 'Income before provision for income taxes']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 2, 'relevance': 3, 'score': 2.5}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Net sales by category', 'iPhone', 'Mac', 'iPad', 'Wearables, Home and Accessories', 'Services']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 2, 'relevance': 3, 'score': 2.5}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Share repurchase activity', 'Equity Securities', 'Publicly Announced Plans', 'Senior Securities', 'Insider Trading Arrangements']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 3, 'depth': 2, 'structure': 3, 'relevance': 3, 'score': 2.75}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Apple Inc.', 'Form 10-Q', 'Financial Statements', "Management's Discussion and Analysis", 'Market Risk']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 3, 'relevance': 3, 'score': 2.75}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Forward-looking statements', 'Financial condition', 'Results of operations', 'Product introductions', 'Macroeconomic conditions']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 1, 'depth': 3, 'structure': 2, 'relevance': 3, 'score': 2.25}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Adjusted Cost', 'Unrealized Gains', 'Unrealized Losses', 'Marketable Securities', 'Fair Value']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 2, 'relevance': 3, 'score': 2.5}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Apple Inc.', 'Consolidated statements of comprehensive income', 'Net income', 'Other comprehensive income', 'Derivative instruments']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 3, 'depth': 1, 'structure': 3, 'relevance': 3, 'score': 2.5}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Apple Inc.', 'Form 10-Q', 'Financial Statements', "Management's Discussion and Analysis", 'Market Risk']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 2, 'relevance': 3, 'score': 2.5}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['European Commission State Aid Decision', 'General Court of the Court of Justice of the European Union', 'Commercial Paper program', 'Share Repurchase Program', 'Apple Inc. Form 10-Q']
# [ragas.testset.evolutions.INFO] seed question generated: "What does the term 'Adjusted Cost' refer to in the context of financial reporting?"
# [ragas.testset.evolutions.INFO] seed question generated: "What allegations are being made against the Company regarding antitrust laws?"
# [ragas.testset.evolutions.INFO] seed question generated: "What information is provided regarding defaults upon senior securities in the context?"
# [ragas.testset.evolutions.INFO] seed question generated: "What are the unrealized gains reported in the financial context provided?"
# [ragas.testset.evolutions.INFO] seed question generated: "What is the purpose of the insider trading arrangement entered into by Tim Cook on May 24, 2024?"
# [ragas.testset.evolutions.INFO] seed question generated: "What is the purpose of the Company's commercial paper program?"
# [ragas.testset.evolutions.INFO] seed question generated: "What section of Apple Inc.'s Form 10-Q contains the financial statements for the fiscal quarter ended June 29, 2024?"
# [ragas.testset.evolutions.INFO] seed question generated: "What are forward-looking statements and how do they relate to the Company's financial reporting?"
# [ragas.testset.evolutions.INFO] seed question generated: "What are the unrealized gains reported in the financial context provided?"
# [ragas.testset.evolutions.INFO] seed question generated: "What was the total amount spent by the Company on its share repurchase program during the nine months ended June 29, 2024?"
# [ragas.testset.evolutions.INFO] seed question generated: "What was the outcome of the European Commission State Aid Decision regarding Ireland's tax opinions for the Company?"
# [ragas.testset.evolutions.INFO] seed question generated: "What is the purpose of the certification provided by Timothy D. Cook in the quarterly report on Form 10-Q of Apple Inc.?"
# [ragas.testset.evolutions.INFO] seed question generated: "What information is provided in the Management's Discussion and Analysis section of Apple Inc.'s Form 10-Q for the fiscal quarter ended June 29, 2024?"
# [ragas.testset.evolutions.INFO] seed question generated: "What was the net income for Apple Inc. for the three months ended June 29, 2024?"
# [ragas.testset.evolutions.INFO] seed question generated: "What was the income before provision for income taxes for Apple Inc. in the three months ended June 29, 2024?"
# [ragas.testset.evolutions.INFO] seed question generated: "What factors contributed to the decrease in net sales for Wearables, Home and Accessories during the third quarter of 2024 compared to the same period in 2023?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks for the definition of the term 'Adjusted Cost' within the context of financial reporting. It is specific, independent, and has a clear intent, making it understandable and answerable based on the details provided. The term 'Adjusted Cost' is clearly identified, and the context of financial reporting is specified, ensuring that the question does not rely on external references or additional context.", 'verdict': 1}
# [ragas.testset.evolutions.DEBUG] [ReasoningEvolution] simple question generated: "What does the term 'Adjusted Cost' refer to in the context of financial reporting?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question asks about the allegations being made against a company regarding antitrust laws. It is clear in its intent, seeking specific information about the nature of the allegations. However, it lacks independence as it does not specify which company is being referred to, making it difficult to answer without additional context. To improve clarity and answerability, the question should specify the company in question.', 'verdict': 0}
# [ragas.testset.evolutions.INFO] rewritten question: "What allegations are being made against the Company regarding antitrust laws?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks for the purpose of the Company's commercial paper program. It is specific and clear in its intent, seeking information about the objective or rationale behind the program. The question is self-contained and does not rely on external references or additional context to be understood or answered. Therefore, it meets the criteria for clarity and answerability.", 'verdict': 1}
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] simple question generated: "What is the purpose of the Company's commercial paper program?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks about 'unrealized gains' reported in a financial context but refers to an unspecified 'financial context provided'. This makes the question unclear and dependent on external information that is not included within the question itself. To improve clarity and answerability, the question should either include the relevant financial context directly within the question or be framed in a way that does not rely on unspecified external information.", 'verdict': 0}
# [ragas.testset.evolutions.INFO] rewritten question: "What are the unrealized gains reported in the financial context provided?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question asks for the net income of Apple Inc. for a specific period (the three months ended June 29, 2024). It is clear in its intent and does not rely on external references or additional context to be understood. The question is specific, independent, and has a clear intent, making it understandable and answerable based on the details provided.', 'verdict': 1}
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks for an explanation of forward-looking statements and their relation to the Company's financial reporting. It is clear in specifying the topic of interest (forward-looking statements) and the context (Company's financial reporting). The intent is straightforward, seeking an understanding of both the definition and the relationship. The question is self-contained and does not rely on external references or prior knowledge beyond general financial reporting concepts.", 'verdict': 1}
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question asks for the purpose of an insider trading arrangement entered into by Tim Cook on May 24, 2024. It is specific in terms of the individual involved (Tim Cook) and the date of the arrangement (May 24, 2024). The intent is clear as it seeks to understand the purpose behind this specific arrangement. The question is self-contained and does not rely on external references or prior knowledge beyond what is provided in the question itself.', 'verdict': 1}
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question asks for the purpose of the certification provided by Timothy D. Cook in the quarterly report on Form 10-Q of Apple Inc. It is specific, independent, and has a clear intent. The question does not rely on external references or prior knowledge beyond what is stated, making it understandable and answerable based on the details provided.', 'verdict': 1}
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question asks for the total amount spent by the Company on its share repurchase program during a specific period (the nine months ended June 29, 2024). It is clear in its intent, specifying the exact information sought (total amount spent) and the time frame of interest. The question is self-contained and does not rely on external references or additional context to be understood and answered. Therefore, it meets the criteria for clarity and answerability.', 'verdict': 1}
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] simple question generated: "What was the total amount spent by the Company on its share repurchase program during the nine months ended June 29, 2024?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks for the outcome of the European Commission State Aid Decision regarding Ireland's tax opinions for a specific company. It is clear in its intent, seeking information about the decision's result. However, it lacks independence as it does not specify which company is being referred to, making it ambiguous. To improve clarity and answerability, the question should specify the company in question.", 'verdict': 0}
# [ragas.testset.evolutions.INFO] rewritten question: "What was the outcome of the European Commission State Aid Decision regarding Ireland's tax opinions for the Company?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks about 'unrealized gains' reported in a 'financial context provided' without including or describing this context within the query. This makes the question unclear and unanswerable for those who do not have access to the unspecified context. For the question to be clear and answerable, it needs to either include the relevant financial context directly within the question or be framed in a way that does not require external information. Providing specific details or examples of the financial context would improve clarity.", 'verdict': 0}
# [ragas.testset.evolutions.INFO] rewritten question: "What are the unrealized gains reported in the financial context provided?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks for information about defaults upon senior securities but refers to 'the context' without providing or describing this context within the query. This makes the question unclear and dependent on unspecified external information. To improve clarity and answerability, the question should either include the relevant context directly within the question or be framed in a way that does not require external references. For example, it could specify the document, report, or dataset where this information is expected to be found.", 'verdict': 0}
# [ragas.testset.evolutions.INFO] rewritten question: "What information is provided regarding defaults upon senior securities in the context?"
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] multicontext question generated: "What financial strategies does the Company employ through its commercial paper program to support its capital return initiatives, particularly in light of recent tax implications and operational expenses?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question asks for the income before provision for income taxes for Apple Inc. for a specific period (the three months ended June 29, 2024). It is clear in specifying the company (Apple Inc.), the financial metric of interest (income before provision for income taxes), and the time frame (three months ended June 29, 2024). The question is self-contained and does not rely on external references or prior knowledge beyond general financial reporting terms. Therefore, it meets the criteria for independence and clear intent.', 'verdict': 1}
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] simple question generated: "What was the income before provision for income taxes for Apple Inc. in the three months ended June 29, 2024?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question is specific and clear, asking for the factors that contributed to the decrease in net sales for Wearables, Home, and Accessories during the third quarter of 2024 compared to the same period in 2023. It does not rely on external references or unspecified contexts, making it understandable and answerable based on the details provided.', 'verdict': 1}
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks for the specific section of Apple Inc.'s Form 10-Q that contains the financial statements for the fiscal quarter ended June 29, 2024. It is clear in specifying the document (Form 10-Q), the company (Apple Inc.), and the time frame (fiscal quarter ended June 29, 2024). The intent is straightforward, seeking the location of financial statements within the document. However, it assumes access to the Form 10-Q document, which may not be readily available to all respondents. To improve independence, the question could be reframed to ask for general guidance on where financial statements are typically found in a Form 10-Q, or it could include a brief description of the document's structure.", 'verdict': 0}
# [ragas.testset.evolutions.INFO] rewritten question: "What section of Apple Inc.'s Form 10-Q contains the financial statements for the fiscal quarter ended June 29, 2024?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question asks about the allegations being made against a company regarding antitrust laws. It is clear in its intent, seeking specific information about the nature of the allegations. However, it lacks independence as it does not specify which company is being referred to. To improve clarity and answerability, the question should specify the company in question.', 'verdict': 0}
# [ragas.testset.evolutions.INFO] retrying evolution: 1 times
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] multicontext question generated: "What was the total expenditure on share repurchases by the Company during the nine months ending June 29, 2024, and how does this relate to its overall liquidity and capital return strategies?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks for specific information provided in the Management's Discussion and Analysis section of Apple Inc.'s Form 10-Q for a specific fiscal quarter. It is clear in specifying the document (Form 10-Q), the company (Apple Inc.), and the time frame (fiscal quarter ended June 29, 2024). However, it assumes access to the Form 10-Q document, which is not provided within the question itself. To improve clarity and answerability, the question could be reframed to ask about typical content found in the Management's Discussion and Analysis section of a Form 10-Q, or it could include a brief summary of the document's content if available.", 'verdict': 0}
# [ragas.testset.evolutions.INFO] rewritten question: "What information is provided in the Management's Discussion and Analysis section of Apple Inc.'s Form 10-Q for the fiscal quarter ended June 29, 2024?"
# [ragas.testset.evolutions.DEBUG] answer generated: {'answer': 'The net income for Apple Inc. for the three months ended June 29, 2024, was $21,448 million.', 'verdict': 1}
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 3, 'relevance': 3, 'score': 2.75}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Apple Inc.', 'Consolidated statements of comprehensive income', 'Net income', 'Other comprehensive income', 'Derivative instruments']
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks about 'unrealized gains' reported in a financial context but refers to an unspecified 'financial context provided'. This makes the question unclear and dependent on external information that is not included within the query itself. To improve clarity and answerability, the question should either include the relevant financial context directly within the question or be framed in a way that does not rely on unspecified external information. For example, it could specify the type of financial report or the specific metrics of interest.", 'verdict': 0}
# [ragas.testset.evolutions.INFO] retrying evolution: 1 times
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question asks for a financial term that connects unrealized gains, losses, and fair value in reporting. It is specific, independent, and has a clear intent, making it understandable and answerable based on the details provided. The question does not rely on external references or additional context, and it clearly seeks a single financial term that links the given concepts.', 'verdict': 1}
# [ragas.testset.evolutions.DEBUG] answer generated: {'answer': 'The purpose of the insider trading arrangement entered into by Tim Cook on May 24, 2024, is to satisfy the affirmative defense conditions of Rule 10b5-1(c) under the Exchange Act. The plan allows for the sale of shares vesting during the duration of the plan, subject to certain price limits, while excluding shares withheld by the Company for tax obligations.', 'verdict': 1}
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] multicontext question generated: "What was the income prior to tax provisions for Apple Inc. during the quarter ending June 29, 2024, and how does this figure relate to the company's overall financial presentation and accounting policies?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks for the outcome of the European Commission State Aid Decision regarding Ireland's tax opinions for a specific company. It is clear in specifying the decision and the context (European Commission State Aid Decision, Ireland's tax opinions), and it seeks a specific outcome. However, the question does not specify which company it refers to, making it ambiguous. To improve clarity and answerability, the question should specify the company in question.", 'verdict': 0}
# [ragas.testset.evolutions.INFO] retrying evolution: 1 times
# [ragas.testset.evolutions.DEBUG] answer generated: {'answer': 'The purpose of the certification provided by Timothy D. Cook in the quarterly report on Form 10-Q of Apple Inc. is to affirm that he has reviewed the report, that it does not contain any untrue statements or omissions that would make the statements misleading, and to ensure that the financial statements fairly present the financial condition and results of operations of the Registrant. Additionally, it involves certifying the effectiveness of disclosure controls and procedures, internal control over financial reporting, and disclosing any significant deficiencies or fraud related to internal controls.', 'verdict': 1}
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 3, 'depth': 3, 'structure': 3, 'relevance': 3, 'score': 3.0}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Certification', 'Financial statements', 'Disclosure controls and procedures', 'Internal control over financial reporting', 'Chief Executive Officer']
# [ragas.testset.evolutions.INFO] seed question generated: "What was the total other comprehensive income for Apple Inc. for the three months ended June 29, 2024?"
# [ragas.testset.evolutions.DEBUG] [ReasoningEvolution] question compressed: "What financial term links unrealized gains, losses, and fair value in reporting?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks about 'unrealized gains' reported in a financial context but refers to an unspecified 'financial context provided'. This makes the question unclear and dependent on external information that is not included within the query itself. To improve clarity and answerability, the question should either include the relevant financial context directly within the question or be framed in a way that does not require additional external references. For example, it could specify the type of financial report or the specific metrics of interest.", 'verdict': 0}
# [ragas.testset.evolutions.INFO] retrying evolution: 1 times
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks for information about defaults upon senior securities but refers to 'the context' without providing or describing this context within the query. This makes the question unclear and dependent on external information that is not included. To improve clarity and answerability, the question should either include the relevant context directly within the question or be framed in a way that does not require external references. For example, it could specify the source or document where this information is expected to be found.", 'verdict': 0}
# [ragas.testset.evolutions.INFO] retrying evolution: 1 times
# [ragas.testset.evolutions.DEBUG] answer generated: {'answer': 'The decrease in net sales for Wearables, Home and Accessories during the third quarter of 2024 compared to the same period in 2023 was primarily due to lower net sales of Wearables.', 'verdict': 1}
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 3, 'relevance': 3, 'score': 2.75}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Segment Reporting', 'ASU 2023-07', 'Critical Accounting Estimates', 'Market Risk', 'Controls and Procedures']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 3, 'depth': 2, 'structure': 3, 'relevance': 3, 'score': 2.75}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Certifications of CEO and CFO', 'Sarbanes-Oxley Act of 2002', 'Form 10-Q', 'Financial condition', 'Results of operations']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 3, 'depth': 3, 'structure': 3, 'relevance': 3, 'score': 3.0}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Certification', 'Financial statements', 'Internal control', 'Disclosure controls', 'Chief Financial Officer']
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 2, 'relevance': 3, 'score': 2.5}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Digital Markets Act Investigations', 'European Union', 'Department of Justice Lawsuit', 'Antitrust laws', 'Epic Games lawsuit']
# ...
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks for the Company's stance on the potential outcomes of legal proceedings and claims. While it is clear in its intent to understand the Company's position, it lacks specificity regarding which company is being referred to and the context of the legal proceedings and claims. This makes it difficult to provide a precise answer without additional context. To improve clarity and answerability, the question could specify the company in question and provide some context or details about the legal proceedings and claims being referred to.", 'verdict': 0}
# [ragas.testset.evolutions.INFO] retrying evolution: 3 times
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question asks for the specific allegations made against a company in a Department of Justice lawsuit. It is clear in its intent, seeking detailed information about the allegations. The question is independent and does not rely on external references or prior knowledge beyond the general understanding of what a lawsuit and allegations are. Therefore, it is specific, independent, and has a clear intent.', 'verdict': 1}
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] simple question generated: "What allegations are made against the Company in the Department of Justice lawsuit?"
# [ragas.testset.filters.DEBUG] evolution filter: {'reason': 'The first question focuses solely on the allegations made against the Company in the DOJ lawsuit, while the second question not only asks about the antitrust issues in the DOJ suit but also seeks to connect them to the EU Digital Markets Act investigations, thus requiring a broader and deeper inquiry.', 'verdict': 0}
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question is clear and specific, asking for the factors that contributed to the decrease in net sales for Greater China during the third quarter of 2024 compared to the third quarter of 2023. It does not rely on external references or unspecified contexts, making it understandable and answerable based on the details provided.', 'verdict': 1}
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] simple question generated: "What factors contributed to the decrease in net sales for Greater China during the third quarter of 2024 compared to the third quarter of 2023?"
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 3, 'relevance': 3, 'score': 2.75}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Forward-looking statements', 'Financial condition', 'Results of operations', 'Product introductions', 'Macroeconomic conditions']
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] multicontext question generated: "What specific antitrust violations is the Company accused of in the DOJ lawsuit, and how do these relate to the ongoing investigations under the EU Digital Markets Act?"
# [ragas.testset.evolutions.INFO] seed question generated: "What factors can impact the Company's results of operations?"
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] multicontext question generated: "What elements led to the 7% decline in Greater China's net sales in Q3 2024, particularly in relation to iPhone performance and currency fluctuations compared to Q3 2023?"
# [ragas.testset.evolutions.DEBUG] answer generated: {'answer': "The Company faces antitrust issues in the DOJ suit alleging monopolization or attempted monopolization in the markets for 'performance smartphones' and 'smartphones' in violation of U.S. antitrust laws. This connects to the EU Digital Markets Act investigations as both involve scrutiny of the Company's practices related to its App Store, with the Commission investigating potential breaches of the DMA, including how developers communicate offers and the default settings on iOS. The investigations and lawsuits highlight concerns about the Company's market behavior and compliance with regulations in both the U.S. and EU.", 'verdict': 1}
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks about the factors that can impact the Company's results of operations. It is clear in its intent, seeking information on various factors that could influence operational outcomes. The question is independent and does not rely on external references or specific prior knowledge, making it understandable and answerable based on general business and financial knowledge.", 'verdict': 1}
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] simple question generated: "What factors can impact the Company's results of operations?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question asks for specific antitrust violations the Company is accused of in the DOJ lawsuit and how these relate to ongoing investigations under the EU Digital Markets Act. It is clear in its intent, specifying the type of information sought (antitrust violations) and the context (DOJ lawsuit and EU Digital Markets Act investigations). The question is independent and does not rely on external references not provided within the question itself. Therefore, it is understandable and answerable based on the details provided.', 'verdict': 1}
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] multicontext question generated: "What elements, including seasonal trends and macroeconomic variables, could influence the operational outcomes of the Company as detailed in its financial reports?"
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] multicontext question compressed: "What antitrust issues does the Company face in the DOJ suit, and how do they connect to the EU Digital Markets Act investigations?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': "The question asks for the elements that led to a 7% decline in Greater China's net sales in Q3 2024, with a particular focus on iPhone performance and currency fluctuations compared to Q3 2023. It is specific in terms of the region (Greater China), the time frame (Q3 2024 compared to Q3 2023), and the factors of interest (iPhone performance and currency fluctuations). The intent is clear, seeking an analysis of the decline in net sales. The question is self-contained and does not rely on external references or unspecified contexts, making it understandable and answerable based on the details provided.", 'verdict': 1}
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] multicontext question compressed: "What caused the 7% drop in Greater China's Q3 2024 net sales, especially regarding iPhone sales and currency changes vs. Q3 2023?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question asks about elements, including seasonal trends and macroeconomic variables, that could influence the operational outcomes of a company as detailed in its financial reports. While it specifies the types of elements of interest (seasonal trends and macroeconomic variables) and the context (operational outcomes in financial reports), it does not specify which company or provide any specific financial reports for reference. This makes the question somewhat vague and reliant on unspecified external documents. To improve clarity and answerability, the question could specify the company in question and, if possible, provide a brief summary or key points from the relevant financial reports.', 'verdict': 0}
# [ragas.testset.evolutions.INFO] rewritten question: "What elements, including seasonal trends and macroeconomic variables, could influence the operational outcomes of the Company as detailed in its financial reports?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question asks about elements, including seasonal trends and macroeconomic variables, that could influence the operational outcomes of a company as detailed in its financial reports. While it specifies the types of elements of interest (seasonal trends and macroeconomic variables) and the context (operational outcomes in financial reports), it does not specify which company or which financial reports are being referred to. This lack of specificity makes the question somewhat vague and dependent on external context. To improve clarity and answerability, the question could specify the company and the particular financial reports or time period of interest.', 'verdict': 0}
# [ragas.testset.evolutions.INFO] retrying evolution: 3 times
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 2, 'relevance': 3, 'score': 2.5}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Earnings Per Share', 'Net income', 'Weighted-average shares', 'Diluted earnings per share', 'Financial Instruments']
# [ragas.testset.filters.DEBUG] evolution filter: {'reason': 'Both questions inquire about the factors leading to the decrease in net sales for Greater China in Q3 2024 compared to Q3 2023. They share the same constraints and requirements, focusing on specific aspects like iPhone sales and currency changes.', 'verdict': 1}
# [ragas.testset.evolutions.INFO] retrying evolution: 4 times
# [ragas.testset.evolutions.INFO] seed question generated: "What were the diluted earnings per share for the three months ended June 29, 2024?"
# [ragas.testset.filters.DEBUG] context scoring: {'clarity': 2, 'depth': 3, 'structure': 2, 'relevance': 3, 'score': 2.5}
# [ragas.testset.evolutions.DEBUG] keyphrases in merged node: ['Interest Rate Risk', 'Derivative instruments', 'Hedged assets/liabilities', 'Trade receivables', 'Vendor non-trade receivables']
# [ragas.testset.filters.DEBUG] evolution filter: {'reason': 'The first question focuses solely on the allegations made against the Company in the DOJ lawsuit, while the second question not only asks about the antitrust issues in the DOJ suit but also seeks to connect them to the EU Digital Markets Act investigations, thus having a broader scope and depth.', 'verdict': 0}
# [ragas.testset.evolutions.INFO] seed question generated: "What measures does the Company take to protect its term debt or marketable securities from fluctuations in interest rates?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question asks for the diluted earnings per share for a specific time period (the three months ended June 29, 2024). It is clear in its intent, specifying the exact financial metric (diluted earnings per share) and the time frame of interest. The question is independent and does not rely on external references or additional context to be understood and answered. Therefore, it meets the criteria for clarity and answerability.', 'verdict': 1}
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] simple question generated: "What were the diluted earnings per share for the three months ended June 29, 2024?"
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question asks about the measures a company takes to protect its term debt or marketable securities from fluctuations in interest rates. It is clear in specifying the financial instruments of interest (term debt, marketable securities) and the specific concern (fluctuations in interest rates). The intent is clear, seeking information on risk management strategies. The question is self-contained and does not rely on external references or prior knowledge beyond general financial concepts.', 'verdict': 1}
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] simple question generated: "What measures does the Company take to protect its term debt or marketable securities from fluctuations in interest rates?"
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] multicontext question generated: "What was the diluted EPS for the quarter ending June 29, 2024, and how does it relate to the net income reported during that period?"
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] multicontext question generated: "What strategies does the Company employ to mitigate both interest rate and foreign exchange rate risks associated with its term debt and marketable securities?"
# [ragas.testset.evolutions.DEBUG] answer generated: {'answer': "The Company faces antitrust issues in the DOJ suit alleging monopolization or attempted monopolization in the markets for 'performance smartphones' and 'smartphones' in violation of U.S. antitrust laws. This connects to the EU Digital Markets Act investigations as both involve scrutiny of the Company's practices related to its App Store, with the Commission investigating potential breaches of the DMA, including how developers communicate offers and the default settings on iOS. The investigations and lawsuits highlight concerns about the Company's market behavior and compliance with regulations in both the U.S. and EU.", 'verdict': 1}
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question is clear and specific, asking for the strategies employed by the Company to mitigate interest rate and foreign exchange rate risks related to its term debt and marketable securities. It does not rely on external references or unspecified contexts, making it understandable and answerable based on the details provided.', 'verdict': 1}
# [ragas.testset.filters.DEBUG] filtered question: {'feedback': 'The question asks for the diluted EPS (Earnings Per Share) for the quarter ending June 29, 2024, and its relation to the net income reported during that period. It is specific and clear in its intent, seeking both a numerical value (diluted EPS) and an explanation of its relationship to net income. The question is self-contained and does not rely on external references or unspecified contexts, making it understandable and answerable based on the details provided.', 'verdict': 1}
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] multicontext question compressed: "What strategies does the Co. use to manage interest and FX risks with its debt and securities?"
# [ragas.testset.evolutions.DEBUG] [MultiContextEvolution] multicontext question compressed: "What's the diluted EPS for Q2 2024 and its relation to net income?"
# [ragas.testset.filters.DEBUG] evolution filter: {'reason': 'The first question focuses specifically on measures to protect term debt or marketable securities from interest rate fluctuations, while the second question encompasses broader strategies for managing both interest and FX risks with debt and securities. This difference in scope and focus leads to different depths and breadths of inquiry.', 'verdict': 0}
# [ragas.testset.filters.DEBUG] evolution filter: {'reason': 'The first question asks specifically for the diluted earnings per share for the three months ended June 29, 2024, while the second question asks for the diluted EPS for Q2 2024 and its relation to net income. The second question has an additional requirement regarding the relationship to net income, leading to a different depth of inquiry.', 'verdict': 0}
# [ragas.testset.evolutions.DEBUG] answer generated: {'answer': 'The diluted earnings per share (EPS) for Q2 2024 is $1.40, and it is related to the net income of $21,448 million.', 'verdict': 1}
# [ragas.testset.evolutions.DEBUG] answer generated: {'answer': 'The Company uses interest rate swaps, options, and other instruments to manage interest rate risk, designating these as either cash flow or fair value hedges. To manage foreign exchange risk, the Company employs forwards, options, and other instruments, also designating them as cash flow or fair value hedges. The Company hedges portions of its forecasted foreign currency exposure associated with revenue and inventory purchases, typically for up to 12 months, and may hedge its exposure to variability in future cash flows for term debt-related foreign currency transactions for up to 18 years.', 'verdict': 1}

# %% [markdown]
# #### 🏗️ Activity #1:
#
# Using the dubgging logs above - trace through a single example of an evolution.
#
# Mark which LLM (Generator, or Critic) was responsible for each step.

# %%
testset.to_pandas()
# Out:
#                                              question  \
# 0   What is the purpose of using derivative instru...
# 1   What are the main requirements introduced by A...
# 2   What was the income tax benefit related to sha...
# 3   What impact can the materialization of risk fa...
# 4   What instruments does the Company use as cash ...
# 5   What is the definition of a shell company acco...
# 6   What was the total shareholders' equity for Ap...
# 7   What are the disclosure requirements related t...
# 8   What was the net income reported by Apple Inc....
# 9   What factors can materially and adversely affe...
# 10  What's Apple's net sales for Q2 2024 vs. last ...
# 11  What was Apple's dividend per share for Q2 202...
# 12  What derivative instruments does the Company u...
# 13  What antitrust claims did Epic Games make agai...
# 14  What changes in stock balances and equity did ...
# 15  What instruments does the Company use for inte...
# 16  When does the fiscal year end, and how often i...
# 17           What's Apple's equity after liabilities?
#
#                                              contexts  \
# 0   [September 30, 2023\nAdjusted\nCost\nUnrealize...
# 1   [Segment Reporting\nIn November 2023, the FASB...
# 2   [Note 9 – Share-Based Compensation\nRestricted...
# 3   [ ended March 30, 2024 (the “second quarter 20...
# 4   [ of reasons, including accounting considerati...
# 5   [Indicate by check mark whether the Registrant...
# 6   [Apple Inc.\nCONDENSED CONSOLIDATED BALANCE SH...
# 7   [Segment Reporting\nIn November 2023, the FASB...
# 8   [Apple Inc.\nCONDENSED CONSOLIDATED STATEMENTS...
# 9   [ ended March 30, 2024 (the “second quarter 20...
# 10  [PART I  —  FINANCIAL INFORMATION\nItem 1. Fin...
# 11  [Apple Inc.\nCONDENSED CONSOLIDATED STATEMENTS...
# 12  [ of reasons, including accounting considerati...
# 13  [PART II  —  OTHER INFORMATION\nItem 1. \nLega...
# 14  [Apple Inc.\nCONDENSED CONSOLIDATED STATEMENTS...
# 15  [Interest Rate Risk\nTo protect the Company’s ...
# 16  [Item 2. \nManagement’s Discussion and Analysi...
# 17  [Apple Inc.\nCONDENSED CONSOLIDATED BALANCE SH...
#
#                                          ground_truth evolution_type  \
# 0   The purpose of using derivative instruments in...         simple
# 1   ASU 2023-07 requires the Company to disclose s...         simple
# 2                                             $ (764)         simple
# 3   The materialization of risk factors can materi...         simple
# 4   The Company uses forwards, options, and other ...         simple
# 5   The answer to given question is not present in...         simple
# 6   The total shareholders' equity for Apple Inc. ...         simple
# 7   ASU 2023-07 requires the Company to disclose s...         simple
# 8   The net income reported by Apple Inc. for the ...         simple
# 9   The factors that can materially and adversely ...         simple
# 10  The answer to given question is not present in...  multi_context
# 11  The answer to given question is not present in...  multi_context
# 12  The Company may use forwards, options, cross-c...  multi_context
# 13  Epic Games filed a lawsuit against the Company...  multi_context
# 14  By June 29, 2024, Apple saw changes in stock b...  multi_context
# 15  The Company uses interest rate swaps, options,...  multi_context
# 16  The Company’s fiscal year ends on the last Sat...      reasoning
# 17  Apple's total shareholders' equity after liabi...      reasoning
#
#                                              metadata  episode_done
# 0   [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 1   [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 2   [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 3   [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 4   [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 5   [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 6   [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 7   [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 8   [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 9   [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 10  [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 11  [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 12  [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 13  [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 14  [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 15  [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 16  [{'source': 'https://s2.q4cdn.com/470004039/fi...          True
# 17  [{'source': 'https://s2.q4cdn.com/470004039/fi...          True

# %% [markdown]
# # 🤝 BREAKOUT ROOM #2

# %% [markdown]
# ## Task 4: LangSmith Dataset
#
# Now we can move on to creating a dataset for LangSmith!
#
# First, we'll need to create a dataset on LangSmith using the `Client`!
#
# We'll name our Dataset to make it easy to work with later.

# %%
from langsmith import Client

client = Client()

dataset_name = "Apple 10-Q Filing Questions - v3"

dataset = client.create_dataset(
    dataset_name=dataset_name,
    description="Questions about Apple's 10-Q Filing"
)

# %% [markdown]
# We'll iterate through the RAGAS created dataframe - and add each example to our created dataset!
#
# > NOTE: We need to conform the outputs to the expected format - which in this case is: `question` and `answer`.

# %%
for test in testset.to_pandas().iterrows():
  client.create_example(
      inputs={
          "question": test[1]["question"]
      },
      outputs={
          "answer": test[1]["ground_truth"]
      },
      metadata={
          "context": test[0]
      },
      dataset_id=dataset.id
  )

# %% [markdown]
# ## Basic RAG Chain
#
# Time for some RAG!
#
# We'll use the Apple 10-Q filing as our data source today!

# %%
rag_documents = PyMuPDFLoader(file_path="https://s2.q4cdn.com/470004039/files/doc_earnings/2024/q3/filing/_10-Q-Q3-2024-As-Filed.pdf").load()

# %% [markdown]
# To keep things simple, we'll just use LangChain's recursive character text splitter!

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 500,
    chunk_overlap = 50
)

rag_documents = text_splitter.split_documents(rag_documents)

# %% [markdown]
# We'll create our vectorstore using OpenAI's [`text-embedding-3-small`](https://platform.openai.com/docs/guides/embeddings/embedding-models) embedding model.

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# %% [markdown]
# As usual, we will power our RAG application with Qdrant!

# %%
from langchain_community.vectorstores import Qdrant

vectorstore = Qdrant.from_documents(
    documents=rag_documents,
    embedding=embeddings,
    location=":memory:",
    collection_name="Apple 10-Q"
)

# %%
retriever = vectorstore.as_retriever()

# %% [markdown]
# To get the "A" in RAG, we'll provide a prompt.

# %%
from langchain.prompts import ChatPromptTemplate

RAG_PROMPT = """\
Given a provided context and question, you must answer the question based only on context.

If you cannot answer the question based on the context - you must say "I don't know".

Context: {context}
Question: {question}
"""

rag_prompt = ChatPromptTemplate.from_template(RAG_PROMPT)

# %% [markdown]
# For our LLM, we will be using TogetherAI's endpoints as well!
#
# We're going to be using Meta Llama 3.1 70B Instruct Turbo - a powerful model which should get us powerful results!

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

# %% [markdown]
# Finally, we can set-up our RAG LCEL chain!

# %%
from operator import itemgetter
from langchain_core.runnables import RunnablePassthrough, RunnableParallel
from langchain.schema import StrOutputParser

rag_chain = (
    {"context": itemgetter("question") | retriever, "question": itemgetter("question")}
    | rag_prompt | llm | StrOutputParser()
)

# %%
rag_chain.invoke({"question" : "Does Apple seem to be in good financial health?"})
# Out:
# "I don't know."

# %% [markdown]
# ## LangSmith Evaluation Set-up
#
# We'll use OpenAI's GPT-4o as our evaluation LLM for our base Evaluators.

# %%
eval_llm = ChatOpenAI(model="gpt-4o")

# %% [markdown]
# We'll be using a number of evaluators - from LangSmith provided evaluators, to a few custom evaluators!

# %%
from langsmith.evaluation import LangChainStringEvaluator, evaluate

qa_evaluator = LangChainStringEvaluator("qa", config={"llm" : eval_llm})

labeled_helpfulness_evaluator = LangChainStringEvaluator(
    "labeled_criteria",
    config={
        "criteria": {
            "helpfulness": (
                "Is this submission helpful to the user,"
                " taking into account the correct reference answer?"
            )
        }
    },
    prepare_data=lambda run, example: {
        "prediction": run.outputs["output"],
        "reference": example.outputs["answer"],
        "input": example.inputs["question"],
    }
)

dope_or_nope_evaluator = LangChainStringEvaluator(
    "criteria",
    config={
        "criteria": {
            "dopeness": "Is this submission dope, lit, or cool?",
        }
    }
)

# %% [markdown]
# #### 🏗️ Activity #2:
#
# Highlight what each evaluator is evaluating.
#
# - `qa_evaluator`:
# - `labeled_helpfulness_evaluator`:
# - `dope_or_nope_evaluator`:

# %% [markdown]
# ## LangSmith Evaluation

# %%
evaluate(
    rag_chain.invoke,
    data=dataset_name,
    evaluators=[
        qa_evaluator,
        labeled_helpfulness_evaluator,
        dope_or_nope_evaluator
    ],
    metadata={"revision_id": "default_chain"},
)
# Out:
# View the evaluation results for experiment: 'worthwhile-speed-7' at:
# https://smith.langchain.com/o/340cd80b-3296-5752-9a9e-58582118073a/datasets/4ac4a33c-30e0-452e-8c4c-6b6d4ce58302/compare?selectedSessions=8dbd4955-d1fb-411e-98d3-8da894f3b3b0
# 0it [00:00, ?it/s]
# <ExperimentResults worthwhile-speed-7>

# %% [markdown]
# ## Dope-ifying Our Application
#
# We'll be making a few changes to our RAG chain to increase its performance on our SDG evaluation test dataset!
#
# - Include a "dope" prompt augmentation
# - Use larger chunks
# - Improve the retriever model to: `text-embedding-3-large`
#
# Let's see how this changes our evaluation!

# %%
DOPE_RAG_PROMPT = """\
Given a provided context and question, you must answer the question based only on context.

If you cannot answer the question based on the context - you must say "I don't know".

You must answer the questions in a dope way, be cool!

Context: {context}
Question: {question}
"""

dope_rag_prompt = ChatPromptTemplate.from_template(DOPE_RAG_PROMPT)

# %%
rag_documents = PyMuPDFLoader(file_path="https://s2.q4cdn.com/470004039/files/doc_earnings/2024/q3/filing/_10-Q-Q3-2024-As-Filed.pdf").load()

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1000,
    chunk_overlap = 50
)

rag_documents = text_splitter.split_documents(rag_documents)

# %% [markdown]
# #### ❓Question #2:
#
# Why would modifying our chunk size modify the performance of our application?

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %% [markdown]
# #### ❓Question #3:
#
# Why would modifying our embedding model modify the performance of our application?

# %%
vectorstore = Qdrant.from_documents(
    documents=rag_documents,
    embedding=embeddings,
    location=":memory:",
    collection_name="Apple 10-Q (Augmented)"
)

# %%
retriever = vectorstore.as_retriever()

# %% [markdown]
# Setting up our new and improved DOPE RAG CHAIN.

# %%
dope_rag_chain = (
    {"context": itemgetter("question") | retriever, "question": itemgetter("question")}
    | dope_rag_prompt | llm | StrOutputParser()
)

# %% [markdown]
# Let's test it on the same output that we saw before.

# %%
dope_rag_chain.invoke({"question" : "Does Apple seem to be in good financial health?"})
# Out:
# "Yo, based on the context, Apple is looking pretty solid! Their net income for the nine months ended June 29, 2024, is $79,000 million, up from $74,039 million the previous year. Plus, their gross margin is on the rise, hitting $136,804 million. They’ve got cash and cash equivalents of $25,565 million, though it's down from $29,965 million. Their total assets are at $331,612 million, even though they’ve dipped a bit from $352,583 million. Overall, they’re still raking in the dough and managing expenses well. So yeah, they seem to be cruising along just fine! 🤑📈"

# %% [markdown]
# Finally, we can evaluate the new chain on the same test set!

# %%
evaluate(
    dope_rag_chain.invoke,
    data=dataset_name,
    evaluators=[
        qa_evaluator,
        labeled_helpfulness_evaluator,
        dope_or_nope_evaluator
    ],
    metadata={"revision_id": "dope_chain"},
)
# Out:
# View the evaluation results for experiment: 'loyal-ornament-15' at:
# https://smith.langchain.com/o/340cd80b-3296-5752-9a9e-58582118073a/datasets/4ac4a33c-30e0-452e-8c4c-6b6d4ce58302/compare?selectedSessions=c0a77ecd-f22a-4be2-98ee-47ca53d966a6
# 0it [00:00, ?it/s]
# <ExperimentResults loyal-ornament-15>

# %% [markdown]
# #### 🏗️ Activity #3:
#
# Provide a screenshot of the difference between the two chains, and explain why you believe certain metrics changed in certain ways.
